# %% [markdown]
# <a href="https://colab.research.google.com/github/tallurinavadeep24-gif/AIML-AMB2150/blob/main/looping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def divide(a, b):
    if b == 0:
        return "Error: Cannot divide by zero."
    return a / b

# example usage
x = float(input("Enter first number: "))
y = float(input("Enter second number: "))
print("Result:", divide(x, y))
# Out:
# Enter first number: 79825
# Enter second number: 5
# Result: 15965.0

# %%
for i in range(3, 9):
 for j in range(3, 9):
    print(i*j, end="\t")
 print()
# Out:
# 9	12	15	18	21	24
# 12	16	20	24	28	32
# 15	20	25	30	35	40
# 18	24	30	36	42	48
# 21	28	35	42	49	56
# 24	32	40	48	56	64

# %%
for i in range(3):
 for j in range(4):
   print("*", end=" ")
 print()
# Out:
# * * * *
# * * * *
# * * * *

# %%
# Calculator
operator = input("Enter an operator (+, -, *, /): ")
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

if operator == "+":
    result = num1 + num2
    print(f"{num1} + {num2} = {result}")
elif operator == "-":
    result = num1 - num2
    print(f"{num1} - {num2} = {result}")
elif operator == "*":
    result = num1 * num2
    print(f"{num1} * {num2} = {result}")
elif operator == "/":
    if num2 != 0:
        result = num1 / num2
        print(f"{num1} / {num2} = {result}")
    else:
        print("Cannot divide by zero!")
else:
    print("Invalid operator!")
